# %% [markdown]
# ## №1.55
# ![image.png](attachment:image.png)\
# Рассмотрим событие А, при котором все три узла работают исправно\
# По условию Р(А1) = 0.9, Р(А2) = 0.95, Р(А3) = 0.8\
# А - все три узла работают безотказно. Тогда, так как прибор работает безотказно, если и 1, и 2, и 3 узлы работают исправно можно посчитать, что:\
# Р(А) = Р(А1)*Р(А2)*Р(А3) = 0.9 * 0.95 * 0.8 = 0.684\
# Тогда, вероятность того, что в течение времени t прибор выйдет из строя будет равна Р(not A) = 1 - Р(А) = 1 - 0.684 = 0.316

# %% [markdown]
# ## 1.58
# ![image.png](attachment:image.png)
# Рассмотрим собырие А, при котором студент выполнит контрольные своевременно.\
# По условию P(A1) = 0.6, P(A2) = 0.5, P(A3) = 0.8\

# %% [markdown]
# ### а)
# Пусть А - событие, при котором студент своевременно выполнит работы по двум дисциплинам.\
# Написание каждой из трех контрольных - это независимые друг от друга события, тогда рассчитаем вероятность события А:
# $$P(A)= P(\overline{A_{1}})*P(A_{2})*P(A_{3}) + P(A_{1})*P(\overline{A_{2}})*P(A_{3})+P(A_{1})*P(A_{2})*P(\overline{A_{3}})$$
# $$ = (1-0.6)*0.5*0.8+0.6*(1-0.5)*0.8 + 0.6*0.5*(1-0.8) =0.46 $$

# %% [markdown]
# ### б)
# Пусть В - событие, при котором студент напишет контрольные хотя бы по двум дисциплинам:\
# $$P(B)= P(\overline{B_{1}})*P(B_{2})*P(B_{3}) + P(B_{1})*P(\overline{B_{2}})*P(B_{3})+P(B_{1})*P(B_{2})*P(\overline{B_{3}}) + P(B_{1})*P(B_{2})*P(B_{3})$$
# $$ = (1-0.6)*0.5*0.8+0.6*(1-0.5)*0.8 + 0.6*0.5*(1-0.8) + 0.6*0.5*0.8 = 0.7$$

# %% [markdown]
# # №1.61
# ![image.png](attachment:image.png)
# Рассмотрим ситуацию А, при которой хотя бы 2 из 3 взятых часов нуждаются в общей чистке механизма:\
# $$P(A)=\frac{\mathrm{C}_{8}^{2}*\mathrm{C}_{12}^{1}+\mathrm{C}_{8}^{3}}{\mathrm{C}_{20}^{3}}$$

# %%
import scipy.special as sc

print(round((sc.comb(8, 2) * sc.comb(12, 1) + sc.comb(8, 3))/(sc.comb(20, 3)) ,4))
# Out:
# 0.3439

# %% [markdown]
# # №1.64
# ![image.png](attachment:image.png)
# ### a)
# Рассмотрим ситуацию А, при которой 3 карандаша будут разных цветов:
# $$P(A)=\frac{\mathrm{C}_{10}^{1}*\mathrm{C}_{3}^{1}*\mathrm{C}_{7}^{1}}{\mathrm{C}_{20}^{3}} = 0.1842$$

# %%
print(round((sc.comb(10, 1) * sc.comb(3, 1) * sc.comb(7, 1)) / (sc.comb(20, 3)), 4))
# Out:
# 0.1842

# %% [markdown]
# ### б)
# Рассмотрим ситуацию В, при которой все 3 карандаша окажутся одного цвета:
# $$P(A)=\frac{\mathrm{C}_{10}^{3}+\mathrm{C}_{3}^{3}+\mathrm{C}_{7}^{3}}{\mathrm{C}_{20}^{3}}$$

# %%
print(round((sc.comb(10, 3) + sc.comb(3, 3) + sc.comb(7, 3)) / (sc.comb(20, 3)), 4))
# Out:
# 0.1368

# %% [markdown]
# # №1.67
# ![image.png](attachment:image.png)\
# Рассмотрим событие $$A_i$$, при которой событие произошло при i-ом испытании.\
# Пусть А - это ситуация, при которой событие произошло хотя бы раз. Тогда $$\overline{A_{1}}$$ - это ситуация, при которой событие не произошло.\
# $$P(\overline{A}) = P(\overline{A_{1}}*\overline{A_{2}}*\overline{A_{3}}* ...*\overline{A_{n}})=$$
# $$= P(\overline{A_{1}}) * P(\overline{A_{2}})*P(\overline{A_{3}})*...*P(\overline{A_{n}}) = 0.6^{n}$$
# Тогда:
# $$P(A) = 1-P(\overline{A})=1-0.6^{n}$$
# $$1 - 0.6^{n} \ge 0.8704$$
# $$0.6^{n} \le 1-0.8704$$
# $$0.6^{n} \le 0.1296$$
# $$n \ge 4$$

# %%
import math

n = math.ceil(math.log(0.1296) / math.log(0.6))
print(f"n ≥ {n}")
# Out:
# n ≥ 4

# %% [markdown]
# # №1.68
# ![image.png](attachment:image.png)\
# Рассмотрим событие А, при котором среди 3 взятых книг хотя бы одна окажется по теории вероятностей.
# $$P(A)=1- \frac{\mathrm{C}_{7}^{3}}{\mathrm{C}_{10}^{3}} = 0.7803$$

# %%
print(round((1 - (sc.comb(7, 3)) / (sc.comb(10, 3))), 4))
# Out:
# 0.7083

# %% [markdown]
# # №1.71
# ![image.png](attachment:image.png)
# $$P(A) = 1 - (P(\overline{A_{1}})*P(\overline{A_{2}})*P(\overline{A_{3}})) = $$
# $$1 - ((1 - 0.2)*(1-0.3)*(1-0.4)) = 1 - (0.8*0.7*0.6) = 1 - 0.336 = 0.664$$
